# %% [markdown]
# ---
# # Phase 1 Final Project: Student Report Card
#
# This project uses **everything from Phase 1**: variables, strings, input, operators, conditionals, loops, and functions.
#
# **Build it completely on your own.** Reference the lessons above but do not copy any code.
#
# ### Requirements:
# 1. Ask for a student name
# 2. Ask for scores in 5 subjects
# 3. Calculate the average
# 4. Assign a grade based on the average
# 5. Check if the student passed all subjects (minimum 40 in each)
# 6. Print a formatted report card
#
# ### Expected Output Format:
# ```
# =============================
#      STUDENT REPORT CARD
# =============================
# Student Name : Priya Sharma
# Subject 1    : 85
# Subject 2    : 72
# Subject 3    : 90
# Subject 4    : 68
# Subject 5    : 55
# -----------------------------
# Total        : 370 / 500
# Average      : 74.0
# Grade        : B
# Status       : PASSED
# =============================
# ```
#
# ### Grading Scale:
# **A:** 90–100 │ **B:** 80–89 │ **C:** 70–79 │ **D:** 60–69 │ **F:** Below 60
#
# **Status is PASSED** only if average ≥ 40 AND no single subject is below 40.
#
# ---
# *Write your solution in the code cell below:*

# %%
# 🏆 YOUR SOLUTION HERE
# Build the Student Report Card

# Hint: start by defining helper functions, then write the main program

# %% [markdown]
# ---
# # Phase 1 Summary & Progress Tracker
#
# ## What You Have Learned
#
# | Lesson | Topic | Key Concepts | Status |
# |--------|-------|--------------|--------|
# | 1 | Variables and Types | int, float, str, bool, type() | [ ] |
# | 2 | Strings In Depth | Methods, f-strings, slicing, indexing | [ ] |
# | 3 | Operators | Arithmetic, comparison, logical, assignment | [ ] |
# | 4 | Input and Output | input(), print(), type conversion | [ ] |
# | 5 | Control Flow | if, elif, else, nested conditions | [ ] |
# | 6 | Loops | for, while, break, continue, nested loops | [ ] |
# | 7 | Functions | def, return, scope, parameters, docstrings | [ ] |
# | 8 | Professional Habits | PEP 8, comments, debugging | [ ] |
# | Project | Report Card | All Phase 1 concepts integrated | [ ] |
#
# ## Phase 1 Mastery Checklist
#
# Before you move to Phase 2, you must be able to do all of these **without looking anything up:**
#
# - [ ] Create and name variables following PEP 8 conventions
# - [ ] Explain the four core data types and when to use each
# - [ ] Write f-strings with number formatting (`.2f`, `.1%`, etc.)
# - [ ] Use all six comparison operators and three logical operators
# - [ ] Write `if-elif-else` with proper indentation
# - [ ] Write a `for` loop over a range and over a string
# - [ ] Write a `while` loop that does not run infinitely
# - [ ] Use `break` and `continue` correctly
# - [ ] Define a function with parameters and a return value
# - [ ] Explain what variable scope means
# - [ ] Read a Python error message and find the root cause
#
# ---
#
# ##  What Is Coming in Phase 2
#
# | Phase 2 Topic | Why It Matters for AI/ML |
# |---------------|--------------------------|
# | Lists | Foundation of NumPy arrays and data batches |
# | List comprehensions | Fast, clean data transformations |
# | Tuples | Immutable sequences, model shapes (e.g., `(32, 28, 28)`) |
# | Dictionaries | Storing hyperparameters, configs, label maps |
# | Sets | Unique values, vocabulary in NLP models |
# | Nested structures | JSON data, multi-dimensional model configs |
#
# >  **Complete the Phase 1 Final Project before moving to Phase 2.** Share your report card code with your mentor for review.
